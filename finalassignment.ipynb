# %%
import pandas as pd
import numpy as np

# %%
#1.import dataset using pandas
a=pd.read_csv("https://raw.githubusercontent.com/SR1608/Datasets/main/covid-data.csv")

# %%
a
# Out:
#       iso_code continent       location      date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  31/12/19          NaN        0.0
# 1          AFG      Asia    Afghanistan  01/01/20          NaN        0.0
# 2          AFG      Asia    Afghanistan  02/01/20          NaN        0.0
# 3          AFG      Asia    Afghanistan  03/01/20          NaN        0.0
# 4          AFG      Asia    Afghanistan  04/01/20          NaN        0.0
# ...        ...       ...            ...       ...          ...        ...
# 57389      NaN       NaN  International  13/11/20        696.0        NaN
# 57390      NaN       NaN  International  14/11/20        696.0        NaN
# 57391      NaN       NaN  International  15/11/20        696.0        NaN
# 57392      NaN       NaN  International  16/11/20        696.0        NaN
# 57393      NaN       NaN  International  17/11/20        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
#2.high level understanding
#no of rows
len(a)
# Out:
# 57394

# %%
#no of columns
len(a.columns)
# Out:
# 49

# %%
#datatypes
a.dtypes
# Out:
# iso_code                               object
# continent                              object
# location                               object
# date                                   object
# total_cases                           float64
# new_cases                             float64
# new_cases_smoothed                    float64
# total_deaths                          float64
# new_deaths                            float64
# new_deaths_smoothed                   float64
# total_cases_per_million               float64
# new_cases_per_million                 float64
# new_cases_smoothed_per_million        float64
# total_deaths_per_million              float64
# new_deaths_per_million                float64
# new_deaths_smoothed_per_million       float64
# reproduction_rate                     float64
# icu_patients                          float64
# icu_patients_per_million              float64
# hosp_patients                         float64
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57394 entries, 0 to 57393
# Data columns (total 49 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso_code                            57071 non-null  object
#  1   continent                           56748 non-null  object
#  2   location                            57394 non-null  object
#  3   date                                57394 non-null  object
#  4   total_cases                         53758 non-null  float64
#  5   new_cases                           56465 non-null  float64
#  6   new_cases_smoothed                  55652 non-null  float64
#  7   total_deaths                        44368 non-null  float64
#  8   new_deaths                          56465 non-null  float64
#  9   new_deaths_smoothed                 55652 non-null  float64
#  10  total_cases_per_million             53471 non-null  float64
# ...

# %%
a.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  5.375800e+04   56465.000000        55652.000000  4.436800e+04
# mean   1.677974e+05    1953.576941         1920.431953  6.858639e+03
# std    1.693038e+06   18269.650340        17777.391785  5.578081e+04
# min    1.000000e+00   -8261.000000         -552.000000  1.000000e+00
# 25%    1.800000e+02       0.000000            0.857000  1.300000e+01
# 50%    2.070000e+03      14.000000           19.429000  8.400000e+01
# 75%    2.235675e+04     235.000000          245.286000  7.270000e+02
# max    5.515465e+07  646281.000000       584981.857000  1.328537e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  56465.000000         55652.000000             53471.000000
# mean      47.054317            46.835439              3139.099982
# std      390.853776           378.272794              6183.455260
# min    -1918.000000          -232.143000                 0.001000
# ...

# %%
a.loc[43534:,]
# Out:
#       iso_code      continent       location      date  total_cases  \
# 43534      LCA  North America    Saint Lucia  19/07/20         23.0
# 43535      LCA  North America    Saint Lucia  20/07/20         23.0
# 43536      LCA  North America    Saint Lucia  21/07/20         23.0
# 43537      LCA  North America    Saint Lucia  22/07/20         23.0
# 43538      LCA  North America    Saint Lucia  23/07/20         23.0
# ...        ...            ...            ...       ...          ...
# 57389      NaN            NaN  International  13/11/20        696.0
# 57390      NaN            NaN  International  14/11/20        696.0
# 57391      NaN            NaN  International  15/11/20        696.0
# 57392      NaN            NaN  International  16/11/20        696.0
# 57393      NaN            NaN  International  17/11/20        696.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 43534        0.0               0.143           NaN         0.0
# ...

# %%
#low level understanding
b=len(pd.unique(a['location']))
b
# Out:
# 216

# %%
a['continent'].value_counts().idxmax()
# Out:
# 'Europe'

# %%
a['total_cases'].agg(['max','mean'])
# Out:
# max     5.515465e+07
# mean    1.677974e+05
# Name: total_cases, dtype: float64

# %%
a['total_deaths'].describe()
# Out:
# count    4.436800e+04
# mean     6.858639e+03
# std      5.578081e+04
# min      1.000000e+00
# 25%      1.300000e+01
# 50%      8.400000e+01
# 75%      7.270000e+02
# max      1.328537e+06
# Name: total_deaths, dtype: float64

# %%
a.groupby(['continent'])['human_development_index'].max()
# Out:
# continent
# Africa           0.797
# Asia             0.933
# Europe           0.953
# North America    0.926
# Oceania          0.939
# South America    0.843
# Name: human_development_index, dtype: float64

# %%
a.groupby(['continent'])['gdp_per_capita'].min()
# Out:
# continent
# Africa            661.240
# Asia             1479.147
# Europe           5189.972
# North America    1653.173
# Oceania          2205.923
# South America    6885.829
# Name: gdp_per_capita, dtype: float64

# %%
a=a.sample(20)

# %%
a1=a[['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index']]

# %%
a1
# Out:
#            continent              location      date  total_cases  \
# 53391           Asia  United Arab Emirates  30/04/20      11929.0
# 22371         Africa                Guinea  14/11/20      12537.0
# 28733           Asia            Kyrgyzstan  01/06/20       1817.0
# 47714         Africa           South Sudan  23/04/20          4.0
# 33676         Africa             Mauritius  24/09/20        367.0
# 55338  South America             Venezuela  30/06/20       5530.0
# 32781         Africa                  Mali  18/06/20       1890.0
# 10109  North America        Cayman Islands  21/06/20        195.0
# 42706         Europe                Russia  15/04/20      21102.0
# 4708   North America              Barbados  14/10/20        210.0
# 26265         Europe                 Italy  20/03/20      41035.0
# 38979           Asia                  Oman  24/01/20          NaN
# 47479           Asia           South Korea  14/04/20      10564.0
# ...

# %%
a.index
# Out:
# Int64Index([53391, 22371, 28733, 47714, 33676, 55338, 32781, 10109, 42706,
#              4708, 26265, 38979, 47479, 17546, 39152, 23172, 48540, 52167,
#             23263, 41483],
#            dtype='int64')

# %%
a.iloc[:,[1,2,3,4,7,39,48]]
# Out:
#            continent              location      date  total_cases  \
# 53391           Asia  United Arab Emirates  30/04/20      11929.0
# 22371         Africa                Guinea  14/11/20      12537.0
# 28733           Asia            Kyrgyzstan  01/06/20       1817.0
# 47714         Africa           South Sudan  23/04/20          4.0
# 33676         Africa             Mauritius  24/09/20        367.0
# 55338  South America             Venezuela  30/06/20       5530.0
# 32781         Africa                  Mali  18/06/20       1890.0
# 10109  North America        Cayman Islands  21/06/20        195.0
# 42706         Europe                Russia  15/04/20      21102.0
# 4708   North America              Barbados  14/10/20        210.0
# 26265         Europe                 Italy  20/03/20      41035.0
# 38979           Asia                  Oman  24/01/20          NaN
# 47479           Asia           South Korea  14/04/20      10564.0
# ...

# %%
a.columns.get_loc('gdp_per_capita')
# Out:
# 39

# %%
#datacleaning

a.drop_duplicates(keep='first')
# Out:
#       iso_code      continent              location      date  total_cases  \
# 53391      ARE           Asia  United Arab Emirates  30/04/20      11929.0
# 22371      GIN         Africa                Guinea  14/11/20      12537.0
# 28733      KGZ           Asia            Kyrgyzstan  01/06/20       1817.0
# 47714      SSD         Africa           South Sudan  23/04/20          4.0
# 33676      MUS         Africa             Mauritius  24/09/20        367.0
# 55338      VEN  South America             Venezuela  30/06/20       5530.0
# 32781      MLI         Africa                  Mali  18/06/20       1890.0
# 10109      CYM  North America        Cayman Islands  21/06/20        195.0
# 42706      RUS         Europe                Russia  15/04/20      21102.0
# 4708       BRB  North America              Barbados  14/10/20        210.0
# 26265      ITA         Europe                 Italy  20/03/20      41035.0
# ...

# %%
a.isna()
# Out:
#        iso_code  continent  location   date  total_cases  new_cases  \
# 53391     False      False     False  False        False      False
# 22371     False      False     False  False        False      False
# 28733     False      False     False  False        False      False
# 47714     False      False     False  False        False      False
# 33676     False      False     False  False        False      False
# 55338     False      False     False  False        False      False
# 32781     False      False     False  False        False      False
# 10109     False      False     False  False        False      False
# 42706     False      False     False  False        False      False
# 4708      False      False     False  False        False      False
# 26265     False      False     False  False        False      False
# 38979     False      False     False  False         True      False
# 47479     False      False     False  False        False      False
# ...

# %%
a.dropna(subset=['continent'])
# Out:
#       iso_code      continent              location      date  total_cases  \
# 53391      ARE           Asia  United Arab Emirates  30/04/20      11929.0
# 22371      GIN         Africa                Guinea  14/11/20      12537.0
# 28733      KGZ           Asia            Kyrgyzstan  01/06/20       1817.0
# 47714      SSD         Africa           South Sudan  23/04/20          4.0
# 33676      MUS         Africa             Mauritius  24/09/20        367.0
# 55338      VEN  South America             Venezuela  30/06/20       5530.0
# 32781      MLI         Africa                  Mali  18/06/20       1890.0
# 10109      CYM  North America        Cayman Islands  21/06/20        195.0
# 42706      RUS         Europe                Russia  15/04/20      21102.0
# 4708       BRB  North America              Barbados  14/10/20        210.0
# 26265      ITA         Europe                 Italy  20/03/20      41035.0
# ...

# %%
a.fillna(0)
# Out:
#       iso_code      continent              location      date  total_cases  \
# 53391      ARE           Asia  United Arab Emirates  30/04/20      11929.0
# 22371      GIN         Africa                Guinea  14/11/20      12537.0
# 28733      KGZ           Asia            Kyrgyzstan  01/06/20       1817.0
# 47714      SSD         Africa           South Sudan  23/04/20          4.0
# 33676      MUS         Africa             Mauritius  24/09/20        367.0
# 55338      VEN  South America             Venezuela  30/06/20       5530.0
# 32781      MLI         Africa                  Mali  18/06/20       1890.0
# 10109      CYM  North America        Cayman Islands  21/06/20        195.0
# 42706      RUS         Europe                Russia  15/04/20      21102.0
# 4708       BRB  North America              Barbados  14/10/20        210.0
# 26265      ITA         Europe                 Italy  20/03/20      41035.0
# ...

# %%
a['date']=pd.to_datetime(a['date'])

# %%
a['date']
# Out:
# 53391   2020-04-30
# 22371   2020-11-14
# 28733   2020-01-06
# 47714   2020-04-23
# 33676   2020-09-24
# 55338   2020-06-30
# 32781   2020-06-18
# 10109   2020-06-21
# 42706   2020-04-15
# 4708    2020-10-14
# 26265   2020-03-20
# 38979   2020-01-24
# 47479   2020-04-14
# 17546   2020-04-05
# 39152   2020-07-15
# 23172   2020-05-23
# 48540   2020-10-21
# 52167   2020-07-20
# 23263   2020-08-22
# 41483   2020-03-27
# Name: date, dtype: datetime64[ns]

# %%
a['month']=pd.DatetimeIndex(a['date']).month

# %%
a
# Out:
#       iso_code      continent              location       date  total_cases  \
# 53391      ARE           Asia  United Arab Emirates 2020-04-30      11929.0
# 22371      GIN         Africa                Guinea 2020-11-14      12537.0
# 28733      KGZ           Asia            Kyrgyzstan 2020-01-06       1817.0
# 47714      SSD         Africa           South Sudan 2020-04-23          4.0
# 33676      MUS         Africa             Mauritius 2020-09-24        367.0
# 55338      VEN  South America             Venezuela 2020-06-30       5530.0
# 32781      MLI         Africa                  Mali 2020-06-18       1890.0
# 10109      CYM  North America        Cayman Islands 2020-06-21        195.0
# 42706      RUS         Europe                Russia 2020-04-15      21102.0
# 4708       BRB  North America              Barbados 2020-10-14        210.0
# 26265      ITA         Europe                 Italy 2020-03-20      41035.0
# ...

# %%
df_groupby=a.groupby(['continent'],as_index=False)
df_groupby.max()
# Out:
#        continent iso_code              location       date  total_cases  \
# 0         Africa      TUN               Tunisia 2020-11-14      12537.0
# 1           Asia      OMN  United Arab Emirates 2020-10-21      59568.0
# 2         Europe      RUS                Russia 2020-04-15      41035.0
# 3  North America      HND              Honduras 2020-10-14      53381.0
# 4  South America      VEN             Venezuela 2020-06-30       5530.0
#
#    new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0       26.0              31.857         107.0         1.0
# 1     1389.0            1510.143         273.0        14.0
# 2     5322.0            3703.143        3407.0       429.0
# 3      562.0             559.143        1632.0        13.0
# 4      233.0             211.714          48.0         4.0
#
#    new_deaths_smoothed  ...  cardiovasc_death_rate  diabetes_prevalence  \
# 0                1.571  ...                336.717                22.02
# ...

# %%
#8.feature engineering
a['total_deaths_to_total_cases']=a['total_deaths']/a['total_cases']

# %%
a.head()
# Out:
#       iso_code continent              location       date  total_cases  \
# 53391      ARE      Asia  United Arab Emirates 2020-04-30      11929.0
# 22371      GIN    Africa                Guinea 2020-11-14      12537.0
# 28733      KGZ      Asia            Kyrgyzstan 2020-01-06       1817.0
# 47714      SSD    Africa           South Sudan 2020-04-23          4.0
# 33676      MUS    Africa             Mauritius 2020-09-24        367.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 53391      549.0             515.286          98.0         9.0
# 22371        0.0              24.857          74.0         0.0
# 28733       69.0              54.857          16.0         0.0
# 47714        0.0               0.000           NaN         0.0
# 33676        0.0               0.286          10.0         0.0
#
#        new_deaths_smoothed  ...  cardiovasc_death_rate  diabetes_prevalence  \
# 53391                6.571  ...                317.840                17.26
# ...

# %%
#9.visualiztion

# %%
import seaborn as sns

# %%
fig=sns.distplot(a['gdp_per_capita'],bins=10,color='red',kde=False)
# Out:
# C:\Users\Suganthi Priya\AppData\Local\Temp\ipykernel_21840\3408341661.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   fig=sns.distplot(a['gdp_per_capita'],bins=10,color='red',kde=False)

# %%
import matplotlib.pyplot as plt
plt.scatter(a['total_cases'],a['gdp_per_capita'])

# %%
sns.catplot(data=a,x='continent',y='total_cases',kind='bar')

# %%
a.to_csv('df_groupby.csv',index=False)
# Out:
# c:\Users\Suganthi Priya\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\internals\blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
